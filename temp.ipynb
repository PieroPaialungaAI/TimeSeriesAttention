# %%
from data import * 
from model import *
data = Dataset()
model = AttentionModel()

# %%
import matplotlib.pyplot as plt
plt.plot(data.X[16])

# %%
model.forward(data.X[0])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 model.forward(data.X[0])
#
# File ~/Desktop/MediumProject/TimeSeriesAttention/TimeSeriesAttention/model.py:23, in AttentionModel.forward(self, x)
#      21 def forward(self, x):
#      22     # x: (batch_size, seq_len, input_dim)
# ---> 23     lstm_out, _ = self.lstm(x)  # (batch_size, seq_len, hidden_dim * 2)
#      25     # Attention weights
#      26     e = self.attention(lstm_out).squeeze(-1)           # (batch_size, seq_len)
#
# File ~/miniforge3/lib/python3.10/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
# ...
